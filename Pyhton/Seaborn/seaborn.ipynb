# %%
! pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %% [markdown]
# ## Visualize Distributions With Seaborn
#
# As a python library which is used for create a graph
# that is best library for create the graph
#
# Seaborn is a library that uses Matplotlib underneath to plot graphs.
#
#  It will be used to visualize random distributions.
#
#   various types of graph in seaborn
# Relational Plots:
#
# scatterplot()
# lineplot()
# Categorical Plots:
#
# stripplot()
# swarmplot()
# boxplot()
# violinplot()
# boxenplot()
# pointplot()
# barplot()
# countplot()
#
#
# Distribution Plots:
#
# histplot()
# kdeplot()
# ecdfplot()
# rugplot()
# Matrix Plots:
#
# heatmap()
# clustermap()
#
# Regression Plots:
#
# lmplot()
# regplot()
# residplot()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = sns.load_dataset('tips') # load dataset form seaborn

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x='total_bill',y='tip',data=data) # scatter plot a graph using seaborn
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(data["total_bill"],bins=100) # histogram ploting
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.kdeplot(data['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.relplot(x='total_bill',y='tip',data=data) # plot a relation gram

# %%
data['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
sns.relplot(x='total_bill',y='tip',hue='time',data=data) # check when tip is max

# %%
sns.relplot(x='total_bill',y='tip',hue='time',style='smoker',data=data) # check when tip is max also they smoke and when they do

# %%
sns.relplot(x='total_bill',y='tip',hue='time',style='smoker',data=data,kind='scatter',col='smoker')

# %%
sns.relplot(x='total_bill',y='tip',hue='time',data=data,style='smoker',col='time') # discriminate on the baseres of time

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y='tip',hue='time',data=data,col='day',row='time',style='smoker')

# %%
sns.relplot(x='total_bill',y='tip',hue='time',data=data)
plt.title('total bill vs tip')
plt.xlabel('total_bill',fontsize = 16 )
plt.ylabel('tip', fontsize = 16)
# Out:
# Text(40.93176041666666, 0.5, 'tip')
