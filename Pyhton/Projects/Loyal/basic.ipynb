# %%
import numpy as np 
import pandas as pd

# %%
df =pd.read_csv('cust_satisfaction.csv')

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103904 non-null  object
#  1   Customer Type               103904 non-null  object
#  2   Type of Travel              103904 non-null  object
#  3   Class                       103904 non-null  object
#  4   satisfaction                103904 non-null  object
#  5   Age                         103904 non-null  int64
#  6   Flight Distance             103904 non-null  int64
#  7   Inflight entertainment      103904 non-null  int64
#  8   Baggage handling            103904 non-null  int64
#  9   Cleanliness                 103904 non-null  int64
#  10  Departure Delay in Minutes  103904 non-null  int64
#  11  Arrival Delay in Minutes    103594 non-null  float64
# dtypes: float64(1), int64(6), object(5)
# ...

# %%
df.describe().sum()
# Out:
# Age                           104168.494670
# Flight Distance               114104.595656
# Inflight entertainment        103923.691148
# Baggage handling              103926.812737
# Cleanliness                   103922.598624
# Departure Delay in Minutes    105561.046519
# Arrival Delay in Minutes      105244.877360
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# ...

# %%
df.isnull().sum()
# Out:
# Gender                        0
# Customer Type                 0
# Type of Travel                0
# Class                         0
# satisfaction                  0
# Age                           0
# Flight Distance               0
# Inflight entertainment        0
# Baggage handling              0
# Cleanliness                   0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(172)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Customer Type'].unique()
# Out:
# array(['Loyal Customer', 'disloyal Customer'], dtype=object)

# %%
dt  = {
    'Loyal Customer' : 1,
    'disloyal Customer' : 0
    }
# dt.keys()
# dt.values()
df['Customer Type']=df['Customer Type'].map(dt)

# %%
df['Customer Type'].unique()
# Out:
# array([1, 0])

# %%
df
# Out:
#         Gender  Customer Type   Type of Travel     Class  \
# 0         Male              1  Personal Travel  Eco Plus
# 1         Male              0  Business travel  Business
# 2       Female              1  Business travel  Business
# 3       Female              1  Business travel  Business
# 4         Male              1  Business travel  Business
# ...        ...            ...              ...       ...
# 103899  Female              0  Business travel       Eco
# 103900    Male              1  Business travel  Business
# 103901    Male              0  Business travel  Business
# 103902  Female              0  Business travel       Eco
# 103903    Male              1  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# ...

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
dt1 = {
    'Male' : 1,
    'Female' : 0}
df['Gender']=df['Gender'].map(dt1)

# %%
df
# Out:
#         Gender  Customer Type   Type of Travel     Class  \
# 0            1              1  Personal Travel  Eco Plus
# 1            1              0  Business travel  Business
# 2            0              1  Business travel  Business
# 3            0              1  Business travel  Business
# 4            1              1  Business travel  Business
# ...        ...            ...              ...       ...
# 103899       0              0  Business travel       Eco
# 103900       1              1  Business travel  Business
# 103901       1              0  Business travel  Business
# 103902       0              0  Business travel       Eco
# 103903       1              1  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# ...

# %%
df['Gender'].unique()
# Out:
# array([1, 0])

# %%
df['Type of Travel'].unique()
# Out:
# array(['Personal Travel', 'Business travel'], dtype=object)

# %%
d = {
    'Personal Travel':0,
    'Business travel':1
}

# %%
df['Type of Travel']=df['Type of Travel'].map(d)

# %%
df
# Out:
#         Gender  Customer Type  Type of Travel     Class  \
# 0            1              1               0  Eco Plus
# 1            1              0               1  Business
# 2            0              1               1  Business
# 3            0              1               1  Business
# 4            1              1               1  Business
# ...        ...            ...             ...       ...
# 103899       0              0               1       Eco
# 103900       1              1               1  Business
# 103901       1              0               1  Business
# 103902       0              0               1       Eco
# 103903       1              1               1  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# ...

# %%
df['Class'].unique()
# Out:
# array(['Eco Plus', 'Business', 'Eco'], dtype=object)

# %%
d1 = {
    'Eco':2,
    'Eco Plus':1,
    'Business':0
}

# %%
df['Class']=df['Class'].map(d1)

# %%
df
# Out:
#         Gender  Customer Type  Type of Travel  Class             satisfaction  \
# 0            1              1               0      1  neutral or dissatisfied
# 1            1              0               1      0  neutral or dissatisfied
# 2            0              1               1      0                satisfied
# 3            0              1               1      0  neutral or dissatisfied
# 4            1              1               1      0                satisfied
# ...        ...            ...             ...    ...                      ...
# 103899       0              0               1      2  neutral or dissatisfied
# 103900       1              1               1      0                satisfied
# 103901       1              0               1      0  neutral or dissatisfied
# 103902       0              0               1      2  neutral or dissatisfied
# 103903       1              1               1      0  neutral or dissatisfied
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['satisfaction'].unique()
# Out:
# array(['neutral or dissatisfied', 'satisfied'], dtype=object)

# %%
d2={
    'neutral or dissatisfied':2,
    'satisfied':1
}

# %%
df['satisfaction'] = df['satisfaction'].map(d2)

# %%
df
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0            1              1               0      1             2   13
# 1            1              0               1      0             2   25
# 2            0              1               1      0             1   26
# 3            0              1               1      0             2   25
# 4            1              1               1      0             1   61
# ...        ...            ...             ...    ...           ...  ...
# 103899       0              0               1      2             2   23
# 103900       1              1               1      0             1   49
# 103901       1              0               1      0             2   30
# 103902       0              0               1      2             2   22
# 103903       1              1               1      0             2   27
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# ...

# %%
df['Baggage handling'].unique()
# Out:
# array([4, 3, 5, 1, 2])

# %%
df
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0            1              1               0      1             2   13
# 1            1              0               1      0             2   25
# 2            0              1               1      0             1   26
# 3            0              1               1      0             2   25
# 4            1              1               1      0             1   61
# ...        ...            ...             ...    ...           ...  ...
# 103899       0              0               1      2             2   23
# 103900       1              1               1      0             1   49
# 103901       1              0               1      0             2   30
# 103902       0              0               1      2             2   22
# 103903       1              1               1      0             2   27
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction  Age  \
# 0            1              1               0      1             2   13
# 1            1              0               1      0             2   25
# 2            0              1               1      0             1   26
# 3            0              1               1      0             2   25
# 4            1              1               1      0             1   61
# ...        ...            ...             ...    ...           ...  ...
# 103899       0              0               1      2             2   23
# 103900       1              1               1      0             1   49
# 103901       1              0               1      0             2   30
# 103902       0              0               1      2             2   22
# 103903       1              1               1      0             2   27
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# ...

# %%
x = df.drop(columns=['Customer Type'],axis=1)
y = df['Customer Type']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#        Gender  Type of Travel  Class  satisfaction  Age  Flight Distance  \
# 71834       0               1      2             2   50              179
# 76517       1               0      2             2   21             1120
# 29502       1               1      0             1   48             3403
# 7185        1               1      0             2   56             1721
# 31081       0               1      2             1   52              933
# ...       ...             ...    ...           ...  ...              ...
# 6284        1               0      2             2   27             1671
# 55092       0               0      0             2   23              255
# 77137       1               1      2             2   39              761
# 861         0               1      0             1   24             1013
# 15837       1               0      2             2   53              305
#
#        Inflight entertainment  Baggage handling  Cleanliness  \
# ...

# %%
y_train
# Out:
# 71834    0
# 76517    1
# 29502    1
# 7185     1
# 31081    1
#         ..
# 6284     1
# 55092    1
# 77137    0
# 861      1
# 15837    1
# Name: Customer Type, Length: 82737, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(20685,))

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9421803239062122

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
adbc = AdaBoostClassifier()

# %%
g = adbc.fit(x_train,y_train)

# %%
adbc_pred = adbc.predict(x_test)

# %%
accuracy_score(adbc_pred,y_test)
# Out:
# 0.9050519700265893
